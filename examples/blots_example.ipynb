# %% [markdown]
# <a href="https://colab.research.google.com/github/TheDenk/hwb/blob/main/examples/blots_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install hwb
# Out:
# ...
#      |████████████████████████████████| 1.4 MB 33.9 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 402 kB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 1.21.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
## Restart runtime to update reinstalled numpy

# %%
# !git clone https://github.com/TheDenk/hwb.git  ## Only for test image)
# Out:
# Cloning into 'hwb'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 29 (delta 1), reused 25 (delta 1), pack-reused 0
# Unpacking objects: 100% (29/29), done.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from hwb import HandWrittenBlot

# %% [markdown]
# ##Help functions

# %%
def show_img(image, figsize=(4, 6), title=None):
    img = image.copy()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=figsize)
    plt.title(title)
    plt.imshow(img)
    plt.axis(False)
    plt.show()

# %% [markdown]
# ##Create images

# %%
img_path = './hwb/images/handwritten_example.png'
image = cv2.imread(img_path)
show_img(image, figsize=(12, 4))

# %% [markdown]
# ##Simple usage

# %%
blots = HandWrittenBlot(None, None)
new_img = blots(image)

show_img(new_img, figsize=(12, 4))

# %% [markdown]
# ##Advanced usage (with configs)

# %%
rect_config = {
    'x': (None, None),
    'y': (None, None),
    'h': (None, 200),
    'w': (None, 200),
}

blot_params = {
    'incline': (-10, 10),
    'intensivity': (0.5, 0.9),
    'transparency': (0.05, 0.4),
    'count': (3, 8),
}

# %%
blots = HandWrittenBlot(rect_config, blot_params)
new_img = blots(image)

show_img(new_img, figsize=(12, 4))
